# %% [markdown]
# # Isotropic Hyperelasticity
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.sandbox.google.com/github/Drenderer/klax/blob/main/docs/examples/isotropic_hyperelasticity.ipynb)
#
# This notebook implements and calibrates an neural network-based isotropic, incompressible hyperelastic material model to Treloar's experimental data using the method presented in [Dammaß et al. (2025)](https://doi.org/10.48550/arXiv.2503.20598). It showcases the basic use of `klax`'s input covex neural network (`FICNN`) and `klax.fit()` function for building and calibrating physics-augmented neural network models.
#
# To run it locally install klax with plotting capability via `pip install 'klax[plot]'`.
#
# We start by importing the required packages for model creation, optimization and plotting. We also import some type aliases and import the `dataclass` module for some simple data handling.

# %%
from dataclasses import dataclass

import equinox as eqx
import jax
import jax.numpy as jnp
import jax.random as jrandom
import optax
from jaxtyping import Array, Float
from matplotlib import pyplot as plt

import klax

# %% [markdown]
# We start by defining a basic class `LoadCase`. It consists of an array of princible stretches `stretch` with shape `(dim, 3)` and the (1,1) component of the first Piola-Kirchhoff stress tensor with shape `(dim, 1)`, where `dim` denotes the number of data points in the load case. We also define a descriptive `title`, which will be used for plotting later on.

# %%
@dataclass
class LoadCase:
    """A simple load case."""

    stretch: Float[Array, "dim 3"]
    pk11_stress: Float[Array, "dim 1"]
    title: str

# %% [markdown]
# In the following, three load cases for *uniaxial tension*, *biaxial tension*, and *pure shear* are created. The data corresponds to Treloar`s experimental results, which were obtained from testing of a rubber material.

# %%
# Uniaxial load case
stretch_1 = jnp.array(
    [
        1.0,
        1.01,
        1.12,
        1.24,
        1.39,
        1.61,
        1.89,
        2.17,
        2.42,
        3.01,
        3.58,
        4.03,
        4.76,
        5.36,
        5.76,
        6.16,
        6.4,
        6.62,
        6.87,
        7.05,
        7.16,
        7.27,
        7.43,
        7.5,
        7.61,
    ]
)
pk11_stress = jnp.array(
    [
        0.0,
        0.03,
        0.14,
        0.23,
        0.32,
        0.41,
        0.5,
        0.58,
        0.67,
        0.85,
        1.04,
        1.21,
        1.58,
        1.94,
        2.29,
        2.67,
        3.02,
        3.39,
        3.75,
        4.12,
        4.47,
        4.85,
        5.21,
        5.57,
        6.3,
    ]
)
stretch = jnp.stack(
    [stretch_1, stretch_1 ** (-0.5), stretch_1 ** (-0.5)], axis=-1
)

uniaxial = LoadCase(stretch, pk11_stress, "Uniaxial tension")

# Biaxial load case
stretch_1 = jnp.array(
    [
        1.0,
        1.04,
        1.08,
        1.12,
        1.14,
        1.2,
        1.31,
        1.42,
        1.69,
        1.94,
        2.49,
        3.03,
        3.43,
        3.75,
        4.03,
        4.26,
        4.44,
    ]
)
pk11_stress = jnp.array(
    [
        0.0,
        0.09,
        0.16,
        0.24,
        0.26,
        0.33,
        0.44,
        0.51,
        0.65,
        0.77,
        0.96,
        1.24,
        1.45,
        1.72,
        1.96,
        2.22,
        2.43,
    ]
)
stretch = jnp.stack([stretch_1, stretch_1, stretch_1 ** (-2)], axis=-1)

biaxial = LoadCase(stretch, pk11_stress, "Biaxial tension")

# Pure shear load case
stretch_1 = jnp.array(
    [
        1.0,
        1.06,
        1.14,
        1.21,
        1.32,
        1.46,
        1.87,
        2.4,
        2.98,
        3.48,
        3.96,
        4.36,
        4.69,
        4.96,
    ]
)
pk11_stress = jnp.array(
    [
        0.0,
        0.07,
        0.16,
        0.24,
        0.33,
        0.42,
        0.59,
        0.76,
        0.93,
        1.11,
        1.28,
        1.46,
        1.62,
        1.79,
    ]
)
stretch = jnp.stack(
    [stretch_1, jnp.ones_like(stretch_1), stretch_1 ** (-1)], axis=-1
)

pure_shear = LoadCase(stretch, pk11_stress, "Pure shear")

# %% [markdown]
# Next, the neural network-based isotropic, incompressible hyperelastic material model according to Dammaß et al. is implemented.

# %%
class PANN(eqx.Module):
    """An neural-network based potential for incompressible hyperelasticity."""

    icnn: klax.nn.FICNN

    def __init__(self, *, key):
        self.icnn = klax.nn.FICNN(
            2,
            "scalar",
            1 * [8],
            use_passthrough=True,
            non_decreasing=True,
            key=key,
        )

    def __call__(self, stretch: Array) -> Array:
        """Evaluate the (1,1) compontent of the first Piola-Kirchhoff stress."""
        stress_coefficients = self.stress_coefficients(stretch)
        return self.piola_kirchhoff_stress(stretch, stress_coefficients)

    def potential(self, isochoric_invariants: Array) -> Array:
        """Compute the hyperelastic potential with energy normalization."""
        # Compute normalization term for F = I
        isochoric_invariants_iden = jnp.array([3, 4])
        pot_iden = self.icnn(isochoric_invariants_iden)
        return self.icnn(isochoric_invariants) - pot_iden

    def isochoric_invariants(self, stretch: Array) -> Array:
        """Compute the isotropic, isochoric invariants."""
        i1 = stretch[0] ** 2 + stretch[1] ** 2 + stretch[2] ** 2
        i2 = (
            (stretch[0] * stretch[1]) ** 2
            + (stretch[0] * stretch[2]) ** 2
            + (stretch[1] * stretch[2]) ** 2
        )
        j = stretch[0] * stretch[1] * stretch[2]

        i1_ = j ** (-2 / 3) * i1
        i2_ = j ** (-4 / 3) * i2
        return jnp.array([i1_, i2_])

    def stress_coefficients(self, stretch: Array) -> Array:
        """Compute the stress coefficients from the potential.

        They correspond to the gradient of the potential with respect to the
        isochoric invariants.
        """
        isochoric_invariants = self.isochoric_invariants(stretch)
        return jax.grad(self.potential)(isochoric_invariants)

    def piola_kirchhoff_stress(
        self, stretch: Array, stress_coefficients: Array
    ):
        """Compute the (1,1) component of the Piola-Kirchoff stress."""
        return 2.0 * (
            stress_coefficients[0]
            * (stretch[0] - stretch[2] ** 2 * stretch[0] ** (-1))
            + stress_coefficients[1]
            * (
                stretch[0] * (stretch[1] ** 2 + stretch[2] ** 2)
                - stretch[2] ** 2
                * stretch[0] ** (-1)
                * (stretch[0] ** 2 + stretch[1] ** 2)
            )
        )

# %% [markdown]
# We choose the *uniaxial* and *biaxial* load cases as calibration data and fit the `PANN` model using `fit()` with the following arguments:
#
# The first argument corresponds to the model that shall be optimized. Its followed by the `data` argument, which could be any PyTree containing at least one Array. However, to use `klax`'s building loss functions the arguments must be of the form `(x, y)`, where both `x` and `y` are the input and output Array respectively.
#
# Next, we specify the number of samples per batch and the axis along which `x` and `y` shall be batched, by setting the `batch_size` and `batch_axes` arguments, respectively.
#
# A loss function is defined using the `loss_fn` argument.
#
# We can select an optimization algorithm by passing any `optax.GradientTransformation` object to the `optimizer` argument. Likewise we can pass a custom `Callback` to the `history` argument to record intermediate training results. In this case we are passing the default `HistoryCallback` with a value of `1000`, which ensures that loss-values are only computed after every 1000-th step, to reduce computational cost.
#
# Finally, a random `key` needs to be passed, which is used internally by the batch generation algorithm.
#
# If required, `fit()` delivers many more advanded capabilities such as passing validation data, defining custom batch axes/loss functions/batch generators as well as the use of `Callbacks` and optimizer states. See the documentation of `fit()` reference for the full list of options.
#
# After finishing calibration, the loss evluation can be plotted by calling the `HistoryCallback.plot()` method on our returne `history` object.

# %%
key = jrandom.PRNGKey(0)
keys = jrandom.split(key, 2)

model = PANN(key=keys[0])
x = jnp.concatenate((uniaxial.stretch, biaxial.stretch), axis=0)
y = jnp.concatenate((uniaxial.pk11_stress, biaxial.pk11_stress), axis=0)

model, history = klax.fit(
    model,
    (x, y),
    batch_size=32,
    batch_axes=0,
    steps=20_000,
    loss=klax.mse,
    optimizer=optax.adam(2e-3),
    key=keys[1],
)

history.plot()
# Out:
# Step:     0: step_loss: nan, training_loss: 1.805e+02
# Step:   100: step_loss: 3.962e+00, training_loss: 3.425e+00
# Step:   200: step_loss: 2.660e-01, training_loss: 3.464e-01
# Step:   300: step_loss: 2.103e-01, training_loss: 3.048e-01
# Step:   400: step_loss: 2.492e-01, training_loss: 2.848e-01
# Step:   500: step_loss: 2.952e-01, training_loss: 2.630e-01
# Step:   600: step_loss: 2.674e-01, training_loss: 2.383e-01
# Step:   700: step_loss: 2.491e-01, training_loss: 2.130e-01
# Step:   800: step_loss: 2.328e-01, training_loss: 1.892e-01
# Step:   900: step_loss: 9.506e-02, training_loss: 1.667e-01
# Step:  1000: step_loss: 1.179e-01, training_loss: 1.477e-01
# Step:  1100: step_loss: 1.413e-01, training_loss: 1.314e-01
# Step:  1200: step_loss: 1.358e-01, training_loss: 1.144e-01
# Step:  1300: step_loss: 8.107e-02, training_loss: 1.013e-01
# Step:  1400: step_loss: 5.871e-02, training_loss: 8.957e-02
# Step:  1500: step_loss: 5.468e-02, training_loss: 7.891e-02
# Step:  1600: step_loss: 8.494e-02, training_loss: 7.020e-02
# Step:  1700: step_loss: 6.879e-02, training_loss: 6.347e-02
# Step:  1800: step_loss: 5.378e-02, training_loss: 5.660e-02
# Step:  1900: step_loss: 5.932e-02, training_loss: 5.113e-02
# Step:  2000: step_loss: 5.834e-02, training_loss: 4.639e-02
# Step:  2100: step_loss: 4.165e-02, training_loss: 4.229e-02
# Step:  2200: step_loss: 4.533e-02, training_loss: 3.939e-02
# Step:  2300: step_loss: 3.846e-02, training_loss: 3.578e-02
# Step:  2400: step_loss: 3.586e-02, training_loss: 3.396e-02
# Step:  2500: step_loss: 3.218e-02, training_loss: 3.067e-02
# Step:  2600: step_loss: 3.408e-02, training_loss: 3.070e-02
# Step:  2700: step_loss: 2.813e-02, training_loss: 2.711e-02
# Step:  2800: step_loss: 1.900e-02, training_loss: 2.565e-02
# Step:  2900: step_loss: 1.231e-02, training_loss: 2.539e-02
# Step:  3000: step_loss: 1.437e-02, training_loss: 2.253e-02
# Step:  3100: step_loss: 2.528e-02, training_loss: 2.103e-02
# Step:  3200: step_loss: 2.483e-02, training_loss: 2.132e-02
# Step:  3300: step_loss: 2.122e-02, training_loss: 1.949e-02
# Step:  3400: step_loss: 1.860e-02, training_loss: 1.819e-02
# Step:  3500: step_loss: 1.858e-02, training_loss: 1.701e-02
# Step:  3600: step_loss: 1.797e-02, training_loss: 1.677e-02
# Step:  3700: step_loss: 1.729e-02, training_loss: 1.555e-02
# Step:  3800: step_loss: 1.741e-02, training_loss: 1.490e-02
# Step:  3900: step_loss: 1.745e-02, training_loss: 1.512e-02
# Step:  4000: step_loss: 1.801e-02, training_loss: 1.403e-02
# Step:  4100: step_loss: 1.679e-02, training_loss: 1.306e-02
# Step:  4200: step_loss: 1.820e-02, training_loss: 1.382e-02
# Step:  4300: step_loss: 1.218e-02, training_loss: 1.210e-02
# Step:  4400: step_loss: 1.320e-02, training_loss: 1.182e-02
# Step:  4500: step_loss: 1.203e-02, training_loss: 1.130e-02
# Step:  4600: step_loss: 6.549e-03, training_loss: 1.336e-02
# Step:  4700: step_loss: 1.234e-02, training_loss: 1.127e-02
# Step:  4800: step_loss: 1.582e-02, training_loss: 1.101e-02
# Step:  4900: step_loss: 1.196e-02, training_loss: 1.007e-02
# Step:  5000: step_loss: 1.120e-02, training_loss: 1.052e-02
# Step:  5100: step_loss: 1.199e-02, training_loss: 9.685e-03
# Step:  5200: step_loss: 5.679e-03, training_loss: 9.427e-03
# Step:  5300: step_loss: 1.085e-02, training_loss: 9.806e-03
# Step:  5400: step_loss: 1.016e-02, training_loss: 8.904e-03
# Step:  5500: step_loss: 9.785e-03, training_loss: 8.691e-03
# Step:  5600: step_loss: 1.242e-02, training_loss: 1.064e-02
# Step:  5700: step_loss: 8.423e-03, training_loss: 8.809e-03
# Step:  5800: step_loss: 1.157e-02, training_loss: 9.928e-03
# Step:  5900: step_loss: 1.046e-02, training_loss: 8.408e-03
# Step:  6000: step_loss: 8.666e-03, training_loss: 8.006e-03
# Step:  6100: step_loss: 8.069e-03, training_loss: 8.023e-03
# Step:  6200: step_loss: 9.583e-03, training_loss: 7.876e-03
# Step:  6300: step_loss: 9.489e-03, training_loss: 9.036e-03
# Step:  6400: step_loss: 4.495e-03, training_loss: 8.038e-03
# Step:  6500: step_loss: 7.293e-03, training_loss: 7.392e-03
# Step:  6600: step_loss: 9.189e-03, training_loss: 7.499e-03
# Step:  6700: step_loss: 7.142e-03, training_loss: 7.658e-03
# Step:  6800: step_loss: 8.002e-03, training_loss: 7.379e-03
# Step:  6900: step_loss: 7.886e-03, training_loss: 7.549e-03
# Step:  7000: step_loss: 8.472e-03, training_loss: 7.186e-03
# Step:  7100: step_loss: 1.019e-02, training_loss: 7.960e-03
# Step:  7200: step_loss: 7.843e-03, training_loss: 6.927e-03
# Step:  7300: step_loss: 7.900e-03, training_loss: 7.198e-03
# Step:  7400: step_loss: 1.190e-02, training_loss: 8.914e-03
# Step:  7500: step_loss: 7.333e-03, training_loss: 7.125e-03
# Step:  7600: step_loss: 8.007e-03, training_loss: 7.108e-03
# Step:  7700: step_loss: 7.763e-03, training_loss: 6.590e-03
# Step:  7800: step_loss: 5.411e-03, training_loss: 6.649e-03
# Step:  7900: step_loss: 7.943e-03, training_loss: 6.548e-03
# Step:  8000: step_loss: 7.988e-03, training_loss: 7.112e-03
# Step:  8100: step_loss: 3.849e-03, training_loss: 7.874e-03
# Step:  8200: step_loss: 8.188e-03, training_loss: 6.575e-03
# Step:  8300: step_loss: 6.570e-03, training_loss: 6.753e-03
# Step:  8400: step_loss: 7.581e-03, training_loss: 6.488e-03
# Step:  8500: step_loss: 5.875e-03, training_loss: 6.357e-03
# Step:  8600: step_loss: 7.453e-03, training_loss: 6.611e-03
# Step:  8700: step_loss: 4.233e-03, training_loss: 6.405e-03
# Step:  8800: step_loss: 7.942e-03, training_loss: 6.246e-03
# Step:  8900: step_loss: 6.542e-03, training_loss: 6.484e-03
# Step:  9000: step_loss: 6.903e-03, training_loss: 6.341e-03
# Step:  9100: step_loss: 6.848e-03, training_loss: 6.311e-03
# Step:  9200: step_loss: 6.663e-03, training_loss: 6.755e-03
# Step:  9300: step_loss: 6.981e-03, training_loss: 6.195e-03
# Step:  9400: step_loss: 6.957e-03, training_loss: 6.759e-03
# Step:  9500: step_loss: 4.373e-03, training_loss: 6.132e-03
# Step:  9600: step_loss: 6.940e-03, training_loss: 6.521e-03
# Step:  9700: step_loss: 4.231e-03, training_loss: 6.259e-03
# Step:  9800: step_loss: 1.088e-02, training_loss: 8.048e-03
# Step:  9900: step_loss: 6.692e-03, training_loss: 6.952e-03
# Step: 10000: step_loss: 6.468e-03, training_loss: 5.949e-03
# Step: 10100: step_loss: 6.253e-03, training_loss: 5.949e-03
# Step: 10200: step_loss: 7.261e-03, training_loss: 6.102e-03
# Step: 10300: step_loss: 5.242e-03, training_loss: 6.038e-03
# Step: 10400: step_loss: 7.033e-03, training_loss: 5.962e-03
# Step: 10500: step_loss: 7.216e-03, training_loss: 8.517e-03
# Step: 10600: step_loss: 8.762e-03, training_loss: 7.834e-03
# Step: 10700: step_loss: 7.102e-03, training_loss: 5.971e-03
# Step: 10800: step_loss: 6.873e-03, training_loss: 7.013e-03
# Step: 10900: step_loss: 6.179e-03, training_loss: 6.018e-03
# Step: 11000: step_loss: 6.628e-03, training_loss: 6.724e-03
# Step: 11100: step_loss: 5.924e-03, training_loss: 5.850e-03
# Step: 11200: step_loss: 8.806e-03, training_loss: 6.095e-03
# Step: 11300: step_loss: 6.806e-03, training_loss: 6.446e-03
# Step: 11400: step_loss: 5.678e-03, training_loss: 6.179e-03
# Step: 11500: step_loss: 3.955e-03, training_loss: 5.966e-03
# Step: 11600: step_loss: 7.070e-03, training_loss: 5.981e-03
# Step: 11700: step_loss: 6.169e-03, training_loss: 9.901e-03
# Step: 11800: step_loss: 4.206e-03, training_loss: 6.285e-03
# Step: 11900: step_loss: 6.861e-03, training_loss: 6.186e-03
# Step: 12000: step_loss: 4.763e-03, training_loss: 5.951e-03
# Step: 12100: step_loss: 7.150e-03, training_loss: 6.086e-03
# Step: 12200: step_loss: 6.070e-03, training_loss: 5.758e-03
# Step: 12300: step_loss: 5.645e-03, training_loss: 6.509e-03
# Step: 12400: step_loss: 5.478e-03, training_loss: 6.767e-03
# Step: 12500: step_loss: 3.747e-03, training_loss: 7.115e-03
# Step: 12600: step_loss: 6.707e-03, training_loss: 5.764e-03
# Step: 12700: step_loss: 5.151e-03, training_loss: 6.255e-03
# Step: 12800: step_loss: 6.781e-03, training_loss: 5.793e-03
# Step: 12900: step_loss: 6.087e-03, training_loss: 6.144e-03
# Step: 13000: step_loss: 6.725e-03, training_loss: 6.671e-03
# Step: 13100: step_loss: 6.327e-03, training_loss: 6.466e-03
# Step: 13200: step_loss: 4.716e-03, training_loss: 5.880e-03
# Step: 13300: step_loss: 6.565e-03, training_loss: 6.450e-03
# Step: 13400: step_loss: 8.797e-03, training_loss: 5.695e-03
# Step: 13500: step_loss: 7.817e-03, training_loss: 6.626e-03
# Step: 13600: step_loss: 4.648e-03, training_loss: 6.055e-03
# Step: 13700: step_loss: 3.947e-03, training_loss: 5.806e-03
# Step: 13800: step_loss: 6.258e-03, training_loss: 6.000e-03
# Step: 13900: step_loss: 4.712e-03, training_loss: 5.843e-03
# Step: 14000: step_loss: 6.613e-03, training_loss: 5.807e-03
# Step: 14100: step_loss: 6.210e-03, training_loss: 5.822e-03
# Step: 14200: step_loss: 7.255e-03, training_loss: 7.433e-03
# Step: 14300: step_loss: 6.276e-03, training_loss: 6.330e-03
# Step: 14400: step_loss: 6.644e-03, training_loss: 6.689e-03
# Step: 14500: step_loss: 4.870e-03, training_loss: 6.724e-03
# Step: 14600: step_loss: 7.642e-03, training_loss: 6.167e-03
# Step: 14700: step_loss: 8.217e-03, training_loss: 6.763e-03
# Step: 14800: step_loss: 4.866e-03, training_loss: 5.915e-03
# Step: 14900: step_loss: 6.615e-03, training_loss: 5.815e-03
# Step: 15000: step_loss: 4.474e-03, training_loss: 6.013e-03
# Step: 15100: step_loss: 7.300e-03, training_loss: 5.890e-03
# Step: 15200: step_loss: 5.960e-03, training_loss: 5.780e-03
# Step: 15300: step_loss: 6.534e-03, training_loss: 5.925e-03
# Step: 15400: step_loss: 6.267e-03, training_loss: 5.866e-03
# Step: 15500: step_loss: 6.492e-03, training_loss: 5.796e-03
# Step: 15600: step_loss: 6.280e-03, training_loss: 5.733e-03
# Step: 15700: step_loss: 8.403e-03, training_loss: 7.501e-03
# Step: 15800: step_loss: 4.749e-03, training_loss: 6.863e-03
# Step: 15900: step_loss: 5.944e-03, training_loss: 6.051e-03
# Step: 16000: step_loss: 5.899e-03, training_loss: 6.004e-03
# Step: 16100: step_loss: 6.781e-03, training_loss: 6.251e-03
# Step: 16200: step_loss: 6.000e-03, training_loss: 5.876e-03
# Step: 16300: step_loss: 5.510e-03, training_loss: 6.285e-03
# Step: 16400: step_loss: 6.542e-03, training_loss: 6.099e-03
# Step: 16500: step_loss: 7.005e-03, training_loss: 5.961e-03
# Step: 16600: step_loss: 4.993e-03, training_loss: 5.719e-03
# Step: 16700: step_loss: 6.560e-03, training_loss: 5.616e-03
# Step: 16800: step_loss: 6.848e-03, training_loss: 5.813e-03
# Step: 16900: step_loss: 5.285e-03, training_loss: 5.697e-03
# Step: 17000: step_loss: 6.067e-03, training_loss: 5.959e-03
# Step: 17100: step_loss: 6.325e-03, training_loss: 7.825e-03
# Step: 17200: step_loss: 5.873e-03, training_loss: 5.639e-03
# Step: 17300: step_loss: 5.500e-03, training_loss: 5.747e-03
# Step: 17400: step_loss: 7.024e-03, training_loss: 6.084e-03
# Step: 17500: step_loss: 9.210e-03, training_loss: 6.606e-03
# Step: 17600: step_loss: 6.502e-03, training_loss: 6.276e-03
# Step: 17700: step_loss: 6.252e-03, training_loss: 5.746e-03
# Step: 17800: step_loss: 6.876e-03, training_loss: 6.023e-03
# Step: 17900: step_loss: 5.099e-03, training_loss: 6.609e-03
# Step: 18000: step_loss: 6.112e-03, training_loss: 5.910e-03
# Step: 18100: step_loss: 7.602e-03, training_loss: 5.840e-03
# Step: 18200: step_loss: 6.290e-03, training_loss: 5.788e-03
# Step: 18300: step_loss: 7.121e-03, training_loss: 6.232e-03
# Step: 18400: step_loss: 5.765e-03, training_loss: 5.860e-03
# Step: 18500: step_loss: 3.944e-03, training_loss: 5.811e-03
# Step: 18600: step_loss: 4.062e-03, training_loss: 6.086e-03
# Step: 18700: step_loss: 1.228e-02, training_loss: 6.889e-03
# Step: 18800: step_loss: 5.493e-03, training_loss: 5.630e-03
# Step: 18900: step_loss: 5.948e-03, training_loss: 6.826e-03
# Step: 19000: step_loss: 5.872e-03, training_loss: 6.117e-03
# Step: 19100: step_loss: 7.170e-03, training_loss: 6.676e-03
# Step: 19200: step_loss: 6.672e-03, training_loss: 6.658e-03
# Step: 19300: step_loss: 4.965e-03, training_loss: 5.624e-03
# Step: 19400: step_loss: 8.198e-03, training_loss: 6.661e-03
# Step: 19500: step_loss: 8.507e-03, training_loss: 8.031e-03
# Step: 19600: step_loss: 7.475e-03, training_loss: 5.681e-03
# Step: 19700: step_loss: 6.861e-03, training_loss: 5.728e-03
# Step: 19800: step_loss: 7.332e-03, training_loss: 6.785e-03
# Step: 19900: step_loss: 6.862e-03, training_loss: 5.725e-03
# Step: 20000: step_loss: 5.987e-03, training_loss: 5.688e-03
# Training took: 0:00:30.975182
# <Axes: title={'center': 'Training History'}, xlabel='Step', ylabel='Metric'>

# %% [markdown]
# A simple utility function is defined to `evaluate` the calibared `model` on a tuple of load cases. Here, the model is jit-compiled using `eqx.filter_jit()` in order to speed up evaluation for large amounts of data.

# %%
def evaluate(model, load_cases: tuple[LoadCase, ...]):
    model = eqx.filter_jit(model)
    _, axs = plt.subplots(1, len(load_cases), figsize=(5 * len(load_cases), 5))

    def plot(ax, x, y, y_pred, title):
        ax.plot(x, y, "x", label="data", color="black")
        ax.plot(x, y_pred, "-", label="data", color="blue")
        ax.set_xlabel(r"$\lambda_1$")
        ax.set_ylabel(r"$P_{11}$/ MPa")
        ax.set_title(title)

    for ax, lc in zip(axs, load_cases):
        pk11_stress_pred = jax.vmap(model)(lc.stretch)
        plot(ax, lc.stretch[:, 0], lc.pk11_stress, pk11_stress_pred, lc.title)

# %% [markdown]
# We evaluate the model on the two training cases (*uniaxial*, *biaxial*) and on the *pure shear* test case. Note, that the model needs to be made callable using `klax.finalize`, since the `FICNN` module contains parameters of type `Unwrappable`, which need to be unwrapped before evaluation.

# %%
model_ = klax.finalize(model)
evaluate(model_, (uniaxial, biaxial, pure_shear))

# %% [markdown]
# Finally, the model parameters can be saved using Equinox's [`equinox.tree_serialize_leaves`](https://docs.kidger.site/equinox/api/serialisation/#equinox.tree_serialise_leaves) function. By default it exports to JAX's or Numpy's binary file format. However, to apply the trained model in a finite element simulation (FEM), we usually need to export the parameters in a more universal format.
#
# For this, the `klax.text_serialize_filter_spec` and `klax.text_deserialize_filter_spec` filter specifications are used, which enable exporting and reading parameters from text files.

# %%
# Save the model parameters to a text file
eqx.tree_serialise_leaves(
    "model.txt", model, filter_spec=klax.text_serialize_filter_spec
)

# Load the model parameters from a text file
loaded_model = eqx.tree_deserialise_leaves(
    "model.txt", model, filter_spec=klax.text_deserialize_filter_spec
)

eqx.tree_pprint(loaded_model)
# Out:
# PANN(
#   icnn=FICNN(
#     layers=(
#       Linear(
#         weight=NonNegative(parameter=f32[2,8]),
#         bias=f32[8],
#         in_features=2,
#         out_features=8,
#         use_bias=True
#       ),
#       InputSplitLinear(
#         weights=(
#           NonNegative(parameter=f32[8,1]), NonNegative(parameter=f32[2,1])
#         ),
#         bias=f32[1],
#         in_features=(8, 2),
#         out_features='scalar',
#         use_bias=True,
#         _num_inputs=2
#       )
#     ),
#     activations=(<PjitFunction of <function softplus at 0x0000020B86D76DE0>>,),
#     final_activation=<function FICNN.<lambda>>,
#     use_bias=True,
#     use_final_bias=True,
#     use_passthrough=True,
#     non_decreasing=True,
#     in_size=2,
#     out_size='scalar',
#     width_sizes=(8,)
#   )
# )
